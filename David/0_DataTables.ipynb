# %%
import pandas as pd
import requests

# %%
pd.set_option('display.max_columns',None)

# %%
# ZORI Zip Seasonally Adjusted
zzs_url = "https://files.zillowstatic.com/research/public_csvs/zori/Zip_ZORI_AllHomesPlusMultifamily_SSA.csv?t=1638579606"
zzs_df = pd.read_csv(zzs_url)

# %%
zzs_df.shape
# Out:
# (2142, 98)

# %%
state_split = zzs_df['MsaName'].str.split(',', expand = True)
zzs_df.insert(3, 'City', state_split[0])
zzs_df.insert(4, 'State', state_split[1])
zzs_df.drop('MsaName', axis = 1, inplace = True)

# %%
zzs_df.head(2)
# Out:
#    RegionID  RegionName  SizeRank      City State  2014-01  2014-02  2014-03  \
# 0     61639       10025         1  New York    NY   2855.0   2870.0   2884.0
# 1     84654       60657         2   Chicago    IL   1315.0   1320.0   1325.0
#
#    2014-04  2014-05  2014-06  2014-07  2014-08  2014-09  2014-10  2014-11  \
# 0   2899.0   2913.0   2928.0   2942.0   2956.0   2970.0   2984.0   2996.0
# 1   1330.0   1334.0   1339.0   1343.0   1348.0   1352.0   1357.0   1361.0
#
#    2014-12  2015-01  2015-02  2015-03  2015-04  2015-05  2015-06  2015-07  \
# 0   3008.0   3021.0   3030.0   3040.0   3050.0   3057.0   3064.0   3071.0
# 1   1365.0   1370.0   1374.0   1378.0   1382.0   1386.0   1390.0   1394.0
#
#    2015-08  2015-09  2015-10  2015-11  2015-12  2016-01  2016-02  2016-03  \
# 0   3076.0   3082.0   3088.0   3092.0   3097.0   3101.0   3103.0   3105.0
# 1   1398.0   1402.0   1407.0   1411.0   1415.0   1419.0   1423.0   1427.0
#
# ...

# %%
zzs_df.sort_values('SizeRank')[['RegionName','City', 'State','2014-01']]
# Out:
#       RegionName      City State  2014-01
# 0          10025  New York    NY   2855.0
# 1          60657   Chicago    IL   1315.0
# 2          10023  New York    NY   3049.0
# 3          77494   Houston    TX   1320.0
# 4          60614   Chicago    IL   1663.0
# ...          ...       ...   ...      ...
# 2137       85701    Tucson    AZ      NaN
# 2138       60606   Chicago    IL   2008.0
# 2139       10006  New York    NY   2936.0
# 2140        2109    Boston    MA      NaN
# 2141       11976  New York    NY  62763.0
#
# [2142 rows x 4 columns]

# %%
zz_url = "https://files.zillowstatic.com/research/public_csvs/zori/Zip_ZORI_AllHomesPlusMultifamily_Smoothed.csv?t=1638579606"
zz_df = pd.read_csv(zz_url)

# %%
zz_df.shape
# Out:
# (2142, 98)

# %%
state_split = zz_df['MsaName'].str.split(',', expand = True)
zz_df.insert(3, 'City', state_split[0])
zz_df.insert(4, 'State', state_split[1])
zz_df.drop('MsaName', axis = 1, inplace = True)

# %%
zz_df.sort_values('SizeRank')[['RegionName','City', 'State','2014-01']]
# Out:
#       RegionName      City State   2014-01
# 0          10025  New York    NY    2792.0
# 1          60657   Chicago    IL    1242.0
# 2          10023  New York    NY    3088.0
# 3          77494   Houston    TX    1370.0
# 4          60614   Chicago    IL    1542.0
# ...          ...       ...   ...       ...
# 2137       85701    Tucson    AZ       NaN
# 2138       60606   Chicago    IL    2073.0
# 2139       10006  New York    NY    2671.0
# 2140        2109    Boston    MA       NaN
# 2141       11976  New York    NY  101087.0
#
# [2142 rows x 4 columns]

# %%
zcta5_url = "https://www2.census.gov/geo/docs/maps-data/data/rel/zcta_tract_rel_10.txt"
zcta5_df = pd.read_csv(zcta5_url)

# %%
state_fips_url = "https://www2.census.gov/geo/docs/reference/state.txt"
stateID = pd.read_csv(state_fips_url, sep='|')
stateID[stateID['STUSAB'] == 'MA']
# Out:
#     STATE STUSAB     STATE_NAME  STATENS
# 21     25     MA  Massachusetts   606926

# %%
convert_df = pd.read_excel('ZiptoZcta2.xlsx')
convert_df[convert_df['ZIP_CODE'] == 1604]
# Out:
#      ZIP_CODE    PO_NAME STATE       ZIP_TYPE   ZCTA     zip_join_type
# 434      1604  Worcester    MA  Zip Code Area  01604  Zip matches ZCTA

# %%
null_columns = zz_df.columns[zz_df.isnull().any()]
null_df = pd.DataFrame(zz_df[null_columns].isnull().sum()).reset_index()
null_df = null_df.rename(columns={'index':'Feature',0:'Count'})

# %%
null_df.sort_values('Count', ascending = False)
# Out:
#     Feature  Count
# 2   2014-03    495
# 1   2014-02    319
# 0   2014-01    298
# 11  2014-12    268
# 10  2014-11    223
# ..      ...    ...
# 68  2019-09      6
# 64  2019-05      6
# 66  2019-07      5
# 67  2019-08      4
# 53  2018-06      3
#
# [94 rows x 2 columns]

# %%
null_columns = zzs_df.columns[zzs_df.isnull().any()]
null_df = pd.DataFrame(zzs_df[null_columns].isnull().sum()).reset_index()
null_df = null_df.rename(columns={'index':'Feature',0:'Count'})

# %%
null_df.sort_values('Count', ascending = False)
# Out:
#     Feature  Count
# 2   2014-03    495
# 1   2014-02    319
# 0   2014-01    298
# 11  2014-12    268
# 10  2014-11    223
# ..      ...    ...
# 68  2019-09      6
# 64  2019-05      6
# 66  2019-07      5
# 67  2019-08      4
# 53  2018-06      3
#
# [94 rows x 2 columns]

# %%
zri_sfdf = pd.read_csv('Zip_Zri_SinglefamilyResidenceRental.csv')
zri_sfdf.sort_values('RegionName')[['RegionName','City', 'State','2014-01']]
# Out:
#        RegionName         City State  2014-01
# 6140         1001       Agawam    MA   1407.0
# 4282         1002      Amherst    MA   1945.0
# 11841        1005        Barre    MA   1281.0
# 7089         1007  Belchertown    MA   1562.0
# 15526        1008    Blandford    MA   1250.0
# ...           ...          ...   ...      ...
# 6954        99669     Soldotna    AK   1270.0
# 6346        99701    Fairbanks    AK   1611.0
# 5704        99705   North Pole    AK   1677.0
# 4721        99709    Fairbanks    AK   1706.0
# 8864        99712    Fairbanks    AK   1654.0
#
# [15836 rows x 4 columns]

# %%
zri_sfdf.dropna()
# Out:
#        RegionID  RegionName          City State  \
# 0         84654       60657       Chicago    IL
# 1         91982       77494          Katy    TX
# 2         84616       60614       Chicago    IL
# 3         91940       77449          Katy    TX
# 4         93144       79936       El Paso    TX
# ...         ...         ...           ...   ...
# 15828     79948       49793    Trout Lake    MI
# 15829     85958       63140       Kinloch    MO
# 15831     99032       97028  Rhododendron    OR
# 15834     58333        1338      Buckland    MA
# 15835     66881       21405     Annapolis    MD
#
#                                   Metro           CountyName  SizeRank  \
# 0              Chicago-Naperville-Elgin          Cook County         1
# 1      Houston-The Woodlands-Sugar Land        Harris County         2
# 2              Chicago-Naperville-Elgin          Cook County         3
# 3      Houston-The Woodlands-Sugar Land        Harris County         4
# ...

# %%
zri_mfdf = pd.read_csv('Zip_Zri_MultifamilyResidenceRental.csv')
zri_mfdf.sort_values('RegionName')[['RegionName','City', 'State','2014-01']]
# Out:
#       RegionName              City State  2014-01
# 1497        1013          Chicopee    MA    928.0
# 1139        1020          Chicopee    MA    933.0
# 865         1040           Holyoke    MA    976.0
# 792         1085         Westfield    MA      NaN
# 1243        1089  West Springfield    MA      NaN
# ...          ...               ...   ...      ...
# 1651       99501         Anchorage    AK      NaN
# 811        99504         Anchorage    AK   1533.0
# 1202       99508         Anchorage    AK   1314.0
# 1336       99654           Wasilla    AK      NaN
# 1717       99701         Fairbanks    AK      NaN
#
# [1861 rows x 4 columns]

# %%
zri_alldf = pd.read_csv('Zip_Zri_AllHomesPlusMultifamily.csv')
zri_alldf.sort_values('RegionName')[['RegionName','City', 'State','2014-01']]
# Out:
#        RegionName         City State  2014-01
# 6034         1001       Agawam    MA   1206.0
# 4248         1002      Amherst    MA   1889.0
# 11441        1005        Barre    MA   1150.0
# 6900         1007  Belchertown    MA   1359.0
# 11937        1010    Brimfield    MA   1180.0
# ...           ...          ...   ...      ...
# 5559        99705   North Pole    AK   1334.0
# 4649        99709    Fairbanks    AK   1335.0
# 8615        99712    Fairbanks    AK      NaN
# 4150        99801       Juneau    AK      NaN
# 7470        99901    Ketchikan    AK      NaN
#
# [13181 rows x 4 columns]

# %%
zri_alldf
# Out:
#        RegionID  RegionName       City State  \
# 0         61639       10025   New York    NY
# 1         84654       60657    Chicago    IL
# 2         61637       10023   New York    NY
# 3         91982       77494       Katy    TX
# 4         84616       60614    Chicago    IL
# ...         ...         ...        ...   ...
# 13176     68966       26291   Snowshoe    WV
# 13177     62697       12720     Bethel    NY
# 13178     68924       26209   Snowshoe    WV
# 13179     75924       41101    Ashland    KY
# 13180     95851       89155  Las Vegas    NV
#
#                                   Metro         CountyName  SizeRank  2010-09  \
# 0           New York-Newark-Jersey City    New York County         1   3031.0
# 1              Chicago-Naperville-Elgin        Cook County         2   1790.0
# 2           New York-Newark-Jersey City    New York County         3   3269.0
# 3      Houston-The Woodlands-Sugar Land      Harris County         4   1547.0
# ...

# %%
zri_alldf.dropna()
# Out:
#        RegionID  RegionName             City State  \
# 3         91982       77494             Katy    TX
# 8         93144       79936          El Paso    TX
# 9         84640       60640          Chicago    IL
# 12        92593       78660     Pflugerville    TX
# 13        97564       94109    San Francisco    CA
# ...         ...         ...              ...   ...
# 13072     96854       92391   Lake Arrowhead    CA
# 13097     96639       92091  Rancho Santa Fe    CA
# 13133     92179       77982    Port O Connor    TX
# 13179     75924       41101          Ashland    KY
# 13180     95851       89155        Las Vegas    NV
#
#                                   Metro             CountyName  SizeRank  \
# 3      Houston-The Woodlands-Sugar Land          Harris County         4
# 8                               El Paso         El Paso County         9
# 9              Chicago-Naperville-Elgin            Cook County        10
# ...

# %%
null_columns = zri_alldf.columns[zri_alldf.isnull().any()]
null_df = pd.DataFrame(zri_alldf[null_columns].isnull().sum()).reset_index()
null_df = null_df.rename(columns={'index':'Feature',0:'Count'})

# %%
null_df.sort_values('Count', ascending = False).head(50)
# Out:
#      Feature  Count
# 2    2010-10   3851
# 3    2010-11   2742
# 4    2010-12   2595
# 5    2011-01   2588
# 7    2011-03   2572
# 6    2011-02   2523
# 8    2011-04   2373
# 1    2010-09   2344
# 14   2011-10   2303
# 16   2011-12   2196
# 15   2011-11   2190
# 17   2012-01   2187
# 13   2011-09   2159
# 35   2013-07   2074
# 21   2012-05   2074
# 39   2013-11   2056
# 23   2012-07   2056
# 11   2011-07   2045
# 22   2012-06   2043
# 9    2011-05   2035
# 12   2011-08   2034
# 36   2013-08   2015
# 19   2012-03   2005
# 20   2012-04   2003
# 41   2014-01   2002
# 18   2012-02   1988
# 10   2011-06   1985
# 38   2013-10   1979
# 40   2013-12   1977
# 24   2012-08   1970
# 37   2013-09   1963
# 34   2013-06   1952
# 29   2013-01   1951
# 31   2013-03   1906
# 26   2012-10   1869
# 101  2019-01   1869
# 28   2012-12   1867
# 33   2013-05   1862
# 25   2012-09   1855
# 110  2019-10   1845
# 30   2013-02   1827
# 27   2012-11   1821
# 32   2013-04   1811
# 49   2014-09   1469
# ...

# %%
zz_df[zz_df['2014-01'].isna()]['State'].value_counts()
# Out:
#  CA    56
#  TX    38
#  CO    19
#  DC    19
#  IL    13
#  NY    12
#  FL    12
#  PA    12
#  MD    11
#  WA     9
#  SC     9
#  TN     9
#  OH     8
#  VA     8
#  NC     8
#  MI     7
#  GA     7
#  CT     6
#  MO     5
#  MA     5
#  AZ     5
#  OR     4
#  MN     3
#  IN     3
#  OK     2
#  LA     2
#  NE     2
#  UT     1
#  WI     1
#  AL     1
#  HI     1
# Name: State, dtype: int64
