# %%
import pandas as pd
df = pd.read_csv('Zip_Zri_AllHomesPlusMultifamily.csv')

# %%
df
# Out:
#        RegionID  RegionName       City State  \
# 0         61639       10025   New York    NY
# 1         84654       60657    Chicago    IL
# 2         61637       10023   New York    NY
# 3         91982       77494       Katy    TX
# 4         84616       60614    Chicago    IL
# ...         ...         ...        ...   ...
# 13176     68966       26291   Snowshoe    WV
# 13177     62697       12720     Bethel    NY
# 13178     68924       26209   Snowshoe    WV
# 13179     75924       41101    Ashland    KY
# 13180     95851       89155  Las Vegas    NV
#
#                                   Metro         CountyName  SizeRank  2010-09  \
# 0           New York-Newark-Jersey City    New York County         1   3031.0
# 1              Chicago-Naperville-Elgin        Cook County         2   1790.0
# 2           New York-Newark-Jersey City    New York County         3   3269.0
# 3      Houston-The Woodlands-Sugar Land      Harris County         4   1547.0
# ...

# %%
cols_2010 = targets.filter(regex='2010')
cols_2011 = targets.filter(regex='2011')
cols_2012 = targets.filter(regex='2012')
cols_2013 = targets.filter(regex='2013')
cols_2014 = targets.filter(regex='2014')
cols_2015 = targets.filter(regex='2015')
cols_2016 = targets.filter(regex='2016')
cols_2017 = targets.filter(regex='2017')
cols_2018 = targets.filter(regex='2018')
cols_2019 = targets.filter(regex='2019')
cols_2020 = targets.filter(regex='2020')

# %%
cols_2010['average'] = cols_2010.mean(axis=1)
cols_2011['average'] = cols_2011.mean(axis=1)
cols_2012['average'] = cols_2012.mean(axis=1)
cols_2013['average'] = cols_2013.mean(axis=1)
cols_2014['average'] = cols_2014.mean(axis=1)
cols_2015['average'] = cols_2015.mean(axis=1)
cols_2016['average'] = cols_2016.mean(axis=1)
cols_2017['average'] = cols_2017.mean(axis=1)
cols_2018['average'] = cols_2018.mean(axis=1)
cols_2019['average'] = cols_2019.mean(axis=1)
cols_2020['average'] = cols_2020.mean(axis=1)
# Out:
# /var/folders/rs/ck6nby4n2s365r7sdf740jt00000gn/T/ipykernel_78571/3034932187.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cols_2010['average'] = cols_2010.mean(axis=1)
# /var/folders/rs/ck6nby4n2s365r7sdf740jt00000gn/T/ipykernel_78571/3034932187.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cols_2011['average'] = cols_2011.mean(axis=1)
# /var/folders/rs/ck6nby4n2s365r7sdf740jt00000gn/T/ipykernel_78571/3034932187.py:3: SettingWithCopyWarning:
# ...

# %%
cols_2017
# Out:
#        2017-01  2017-02  2017-03  2017-04  2017-05  2017-06  2017-07  2017-08  \
# 0       5009.0      NaN      NaN      NaN      NaN   3988.0      NaN      NaN
# 1       2108.0   2104.0   2117.0   2118.0   2125.0   2146.0   2168.0   2183.0
# 2          NaN      NaN      NaN      NaN      NaN   4176.0      NaN   3997.0
# 3       1765.0   1763.0   1762.0   1760.0   1752.0   1753.0   1757.0   1763.0
# 4       2313.0   2307.0   2319.0   2325.0   2338.0   2364.0   2389.0   2401.0
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 13176    993.0    984.0    968.0    965.0    964.0    964.0    955.0    943.0
# 13177   1162.0   1154.0   1147.0   1145.0   1155.0   1172.0   1186.0   1206.0
# 13178    746.0    752.0    765.0    770.0    770.0    771.0    764.0    761.0
# 13179    860.0    855.0    851.0    850.0    855.0    861.0    867.0    863.0
# 13180   1263.0   1263.0   1259.0   1267.0   1272.0   1278.0   1284.0   1289.0
#
# ...

# %%
year_avgs = pd.DataFrame({'geo_id':df.RegionName,
             '2010':cols_2010.average,
             '2011':cols_2011.average,
             '2012':cols_2012.average,
             '2013':cols_2013.average,
             '2014':cols_2014.average,
             '2015':cols_2015.average,
             '2016':cols_2016.average,
             '2017':cols_2017.average,
             '2018':cols_2018.average,
             '2019':cols_2019.average,
             '2020':cols_2020.average})
year_avgs
# Out:
#        geo_id     2010         2011         2012         2013         2014  \
# 0       10025  3033.75  2864.666667  2967.000000  3144.666667  3274.375000
# 1       60657  1783.75  1787.250000  1866.833333  1955.666667  2005.666667
# 2       10023  3303.75  3074.250000  3073.833333  3198.250000  3322.250000
# 3       77494  1554.00  1584.500000  1630.583333  1786.833333  1956.833333
# 4       60614  1919.00  1897.583333  2014.666667  2148.000000  2202.583333
# ...       ...      ...          ...          ...          ...          ...
# 13176   26291   946.00   957.272727   949.545455   979.272727   949.363636
# 13177   12720  1399.00  1200.125000  1152.181818  1200.166667  1209.750000
# 13178   26209      NaN          NaN          NaN          NaN   692.200000
# 13179   41101   758.25   782.333333   846.083333   832.750000   836.166667
# 13180   89155  1099.75  1096.750000  1087.916667  1099.333333  1141.000000
#
# ...

# %%
year_avgs.to_csv('year_avgs.csv')
